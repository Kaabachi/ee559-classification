# %%
from Utils import *

# %%
CNN_no_weight_no_aux = [[],[]]
CNN_no_weight_with_aux = [[],[]]
CNN_with_weight_no_aux = [[],[]]
CNN_with_weight_with_aux = [[],[]]

for i in range(15):
    train_error, test_error = test_models('CNN', activation_conv = 'tanh',
                                          activation_fully = 'tanh', display = False)
    CNN_no_weight_no_aux[0].append(train_error[0])
    CNN_no_weight_no_aux[1].append(test_error[0])
    CNN_no_weight_with_aux[0].append(train_error[1])
    CNN_no_weight_with_aux[1].append(test_error[1])
    CNN_with_weight_no_aux[0].append(train_error[2])
    CNN_with_weight_no_aux[1].append(test_error[2])
    CNN_with_weight_with_aux[0].append(train_error[3])
    CNN_with_weight_with_aux[1].append(test_error[3])
# Out:
# Parameters:
#  	 Net = CNN
#  	 Activation function convolution layers = tanh
#  	 Activation function fully connected layers = tanh
#
# Weight Sharing = 'False', Auxilary Loss = 'False'
# Training accuracy = 24.10%, Testing accuracy = 23.60%
#
# Weight Sharing = 'False', Auxilary Loss = 'True'
# Training accuracy = 23.30%, Testing accuracy = 25.20%
#
# Weight Sharing = 'True', Auxilary Loss = 'False'
# Training accuracy = 18.60%, Testing accuracy = 20.50%
#
# Weight Sharing = 'True', Auxilary Loss = 'True'
# Training accuracy = 17.20%, Testing accuracy = 18.40%
#
# Parameters:
#  	 Net = CNN
#  	 Activation function convolution layers = tanh
#  	 Activation function fully connected layers = tanh
#
# Weight Sharing = 'False', Auxilary Loss = 'False'
# Training accuracy = 27.40%, Testing accuracy = 28.40%
#
# Weight Sharing = 'False', Auxilary Loss = 'True'
# Training accuracy = 23.60%, Testing accuracy = 24.60%
#
# Weight Sharing = 'True', Auxilary Loss = 'False'
# ...

# %%
LeNet_no_weight_no_aux = [[],[]]
LeNet_no_weight_with_aux = [[],[]]
LeNet_with_weight_no_aux = [[],[]]
LeNet_with_weight_with_aux = [[],[]]

for i in range(15):
    train_error, test_error = test_models('LeNet', activation_conv = 'tanh',
                                          activation_fully = 'tanh', display = False)
    LeNet_no_weight_no_aux[0].append(train_error[0])
    LeNet_no_weight_no_aux[1].append(test_error[0])
    LeNet_no_weight_with_aux[0].append(train_error[1])
    LeNet_no_weight_with_aux[1].append(test_error[1])
    LeNet_with_weight_no_aux[0].append(train_error[2])
    LeNet_with_weight_no_aux[1].append(test_error[2])
    LeNet_with_weight_with_aux[0].append(train_error[3])
    LeNet_with_weight_with_aux[1].append(test_error[3])
# Out:
# Parameters:
#  	 Net = LeNet
#  	 Activation function convolution layers = tanh
#  	 Activation function fully connected layers = tanh
#
# Weight Sharing = 'False', Auxilary Loss = 'False'
# Training accuracy = 29.90%, Testing accuracy = 27.50%
#
# Weight Sharing = 'False', Auxilary Loss = 'True'
# Training accuracy = 25.20%, Testing accuracy = 27.00%
#
# Weight Sharing = 'True', Auxilary Loss = 'False'
# Training accuracy = 27.60%, Testing accuracy = 28.50%
#
# Weight Sharing = 'True', Auxilary Loss = 'True'
# Training accuracy = 22.20%, Testing accuracy = 22.70%
#
# Parameters:
#  	 Net = LeNet
#  	 Activation function convolution layers = tanh
#  	 Activation function fully connected layers = tanh
#
# Weight Sharing = 'False', Auxilary Loss = 'False'
# Training accuracy = 27.40%, Testing accuracy = 25.40%
#
# Weight Sharing = 'False', Auxilary Loss = 'True'
# Training accuracy = 25.90%, Testing accuracy = 24.40%
#
# Weight Sharing = 'True', Auxilary Loss = 'False'
# ...

# %%
sum(CNN_with_weight_with_aux[1])/len(CNN_with_weight_with_aux[1])
# Out:
# 17.433333333333334

# %%
import numpy as np

# %%
np.std(CNN_with_weight_with_aux[1])
# Out:
# 17.433333333333334

# %%
CNN_with_weight_with_aux[1]
