# %%
from Models import *
from Utils import *

# %%
baseline_errors = []
fully_errors = []
resnet_errors = []

print('************** FullyConnectedNet ************** ')
for i in range(10):
    model_fully, error_fully, train_error_fully, test_error_fully = train_Net_model('FullyConnectedNet',
                                                                    lr=0.1 ,verbose = False)
    fully_errors.append(test_error_fully[-1])

print('************** BaselineNet ************** ')    
for i in range(10):    
    model_baseline, error_baseline, train_error_baseline, test_error_baseline = train_Net_model('BaselineNet',
                                                                    lr=0.1 ,verbose = False)
    baseline_errors.append(test_error_baseline[-1])

print('************** ResNet ************** ')
for i in range(10):    
    model_resnet, error_resnet, train_error_resnet, test_error_resnet = train_Net_model('ResNet',
                                                                    lr=0.1 ,verbose = False)
    resnet_errors.append(test_error_resnet[-1])
# Out:
# ************** FullyConnectedNet **************
# Training accuracy = 17.50%, Testing accuracy = 27.10%
#
# Training accuracy = 6.30%, Testing accuracy = 20.00%
#
# Training accuracy = 4.70%, Testing accuracy = 18.90%
#
# Training accuracy = 12.30%, Testing accuracy = 22.40%
#
# Training accuracy = 6.70%, Testing accuracy = 21.10%
#
# Training accuracy = 5.60%, Testing accuracy = 21.50%
#
# Training accuracy = 7.70%, Testing accuracy = 24.70%
#
# Training accuracy = 7.40%, Testing accuracy = 23.40%
#
# Training accuracy = 14.20%, Testing accuracy = 26.20%
#
# Training accuracy = 15.90%, Testing accuracy = 26.10%
#
# ************** BaselineNet **************
# Training accuracy = 3.00%, Testing accuracy = 17.30%
#
# Training accuracy = 0.40%, Testing accuracy = 18.30%
#
# Training accuracy = 4.50%, Testing accuracy = 19.40%
#
# Training accuracy = 1.80%, Testing accuracy = 19.90%
#
# Training accuracy = 3.90%, Testing accuracy = 22.00%
#
# Training accuracy = 0.70%, Testing accuracy = 19.30%
#
# Training accuracy = 1.30%, Testing accuracy = 18.90%
#
# Training accuracy = 3.10%, Testing accuracy = 20.60%
#
# Training accuracy = 3.50%, Testing accuracy = 19.60%
#
# Training accuracy = 4.30%, Testing accuracy = 22.90%
#
# ************** ResNet **************
# Training accuracy = 1.50%, Testing accuracy = 23.90%
#
# Training accuracy = 0.00%, Testing accuracy = 20.70%
#
# Training accuracy = 0.00%, Testing accuracy = 19.50%
#
# Training accuracy = 1.10%, Testing accuracy = 22.00%
#
# Training accuracy = 0.00%, Testing accuracy = 24.00%
#
# Training accuracy = 0.00%, Testing accuracy = 21.00%
#
# Training accuracy = 0.00%, Testing accuracy = 21.90%
#
# Training accuracy = 0.00%, Testing accuracy = 20.20%
#
# Training accuracy = 0.00%, Testing accuracy = 21.00%
#
# Training accuracy = 0.00%, Testing accuracy = 21.20%

# %%
cnn0_errors = []
cnn1_errors = []
cnn2_errors = []
cnn3_errors = []

print('**************** CNN ***************')
print('Weight Sharing = ''False'', Auxilary Loss = ''False''')
for i in range(10):
    model_cnn0, error_cnn0, train_error_cnn0, test_error_cnn0 = train_Net_model('CNN',
                                                                    weight_sharing = False, auxilary_loss = False,
                                                                    lr=0.1 ,verbose = False)
    cnn0_errors.append(test_error_cnn0[-1])

print('Weight Sharing = ''True'', Auxilary Loss = ''False''')
for i in range(10):
    model_cnn1, error_cnn1, train_error_cnn1, test_error_cnn1 = train_Net_model('CNN',
                                                                    weight_sharing = True, auxilary_loss = False,
                                                                    lr=0.1 ,verbose = False)
    cnn1_errors.append(test_error_cnn1[-1])

print('Weight Sharing = ''False'', Auxilary Loss = ''True''')
for i in range(10):
    model_cnn2, error_cnn2, train_error_cnn2, test_error_cnn2 = train_Net_model('CNN',
                                                                    weight_sharing = False, auxilary_loss = True,
                                                                    lr=0.1 ,verbose = False)
    cnn2_errors.append(test_error_cnn2[-1])

print('Weight Sharing = ''True'', Auxilary Loss = ''True''')
for i in range(10):
    model_cnn3, error_cnn3, train_error_cnn3, test_error_cnn3 = train_Net_model('CNN',
                                                                    weight_sharing = True, auxilary_loss = True,
                                                                    lr=0.1 ,verbose = False)
    cnn3_errors.append(test_error_cnn3[-1])
# Out:
# **************** CNN ***************
# Weight Sharing = False, Auxilary Loss = False
# Training accuracy = 8.80%, Testing accuracy = 17.90%
#
# Training accuracy = 15.50%, Testing accuracy = 21.20%
#
# Training accuracy = 10.30%, Testing accuracy = 18.60%
#
# Training accuracy = 14.10%, Testing accuracy = 18.20%
#
# Training accuracy = 9.90%, Testing accuracy = 18.80%
#
# Training accuracy = 25.60%, Testing accuracy = 28.40%
#
# Training accuracy = 10.70%, Testing accuracy = 16.00%
#
# Training accuracy = 15.70%, Testing accuracy = 22.50%
#
# Training accuracy = 12.90%, Testing accuracy = 24.20%
#
# Training accuracy = 9.80%, Testing accuracy = 18.80%
#
# Weight Sharing = True, Auxilary Loss = False
# Training accuracy = 1.30%, Testing accuracy = 17.00%
#
# Training accuracy = 1.10%, Testing accuracy = 15.10%
#
# Training accuracy = 1.90%, Testing accuracy = 16.70%
#
# Training accuracy = 0.90%, Testing accuracy = 15.40%
#
# Training accuracy = 0.00%, Testing accuracy = 15.70%
#
# Training accuracy = 2.60%, Testing accuracy = 15.70%
#
# Training accuracy = 0.00%, Testing accuracy = 17.00%
#
# Training accuracy = 4.30%, Testing accuracy = 12.80%
#
# Training accuracy = 0.20%, Testing accuracy = 15.60%
#
# Training accuracy = 0.30%, Testing accuracy = 16.30%
#
# Weight Sharing = False, Auxilary Loss = True
# Training accuracy = 8.50%, Testing accuracy = 18.60%
#
# Training accuracy = 11.70%, Testing accuracy = 19.70%
#
# Training accuracy = 9.80%, Testing accuracy = 16.90%
#
# Training accuracy = 8.10%, Testing accuracy = 16.10%
#
# Training accuracy = 9.70%, Testing accuracy = 15.00%
#
# Training accuracy = 9.70%, Testing accuracy = 15.00%
#
# Training accuracy = 6.60%, Testing accuracy = 14.70%
#
# Training accuracy = 10.00%, Testing accuracy = 17.20%
#
# Training accuracy = 11.60%, Testing accuracy = 20.50%
#
# Training accuracy = 12.40%, Testing accuracy = 22.70%
#
# Weight Sharing = True, Auxilary Loss = True
# Training accuracy = 1.50%, Testing accuracy = 11.50%
#
# Training accuracy = 1.00%, Testing accuracy = 11.50%
#
# Training accuracy = 3.30%, Testing accuracy = 14.10%
#
# Training accuracy = 0.30%, Testing accuracy = 11.50%
#
# Training accuracy = 3.40%, Testing accuracy = 14.70%
#
# Training accuracy = 1.60%, Testing accuracy = 15.20%
#
# Training accuracy = 0.30%, Testing accuracy = 11.00%
#
# Training accuracy = 1.70%, Testing accuracy = 12.60%
#
# Training accuracy = 1.20%, Testing accuracy = 11.60%
#
# Training accuracy = 0.60%, Testing accuracy = 14.80%

# %%
lenet0_errors = []
lenet1_errors = []
lenet2_errors = []
lenet3_errors = []

print('**************** LeNet ***************')
print('Weight Sharing = ''False'', Auxilary Loss = ''False''')
for i in range(10):
    model_lenet0, error_lenet0, train_error_lenet0, test_error_lenet0 = train_Net_model('LeNet',
                                                                    weight_sharing = False, auxilary_loss = False,
                                                                    lr=0.1 ,verbose = False)
    lenet0_errors.append(test_error_lenet0[-1])

print('Weight Sharing = ''True'', Auxilary Loss = ''False''')
for i in range(10):
    model_lenet1, error_lenet1, train_error_lenet1, test_error_lenet1 = train_Net_model('LeNet',
                                                                    weight_sharing = True, auxilary_loss = False,
                                                                    lr=0.1 ,verbose = False)
    lenet1_errors.append(test_error_lenet1[-1])

print('Weight Sharing = ''False'', Auxilary Loss = ''True''')
for i in range(10):
    model_lenet2, error_lenet2, train_error_lenet2, test_error_lenet2 = train_Net_model('LeNet',
                                                                    weight_sharing = False, auxilary_loss = True,
                                                                    lr=0.1 ,verbose = False)
    lenet2_errors.append(test_error_lenet2[-1])

print('Weight Sharing = ''True'', Auxilary Loss = ''True''')
for i in range(10):
    model_lenet3, error_lenet3, train_error_lenet3, test_error_lenet3 = train_Net_model('LeNet',
                                                                    weight_sharing = True, auxilary_loss = True,
                                                                    lr=0.1 ,verbose = False)
    lenet3_errors.append(test_error_lenet3[-1])
# Out:
# **************** LeNet ***************
# Weight Sharing = False, Auxilary Loss = False
# Training accuracy = 19.80%, Testing accuracy = 26.90%
#
# Training accuracy = 21.00%, Testing accuracy = 24.80%
#
# Training accuracy = 19.50%, Testing accuracy = 25.30%
#
# Training accuracy = 22.20%, Testing accuracy = 22.60%
#
# Training accuracy = 20.20%, Testing accuracy = 24.30%
#
# Training accuracy = 21.50%, Testing accuracy = 21.10%
#
# Training accuracy = 21.70%, Testing accuracy = 22.30%
#
# Training accuracy = 16.60%, Testing accuracy = 21.00%
#
# Training accuracy = 20.60%, Testing accuracy = 22.80%
#
# Training accuracy = 21.00%, Testing accuracy = 24.90%
#
# Weight Sharing = True, Auxilary Loss = False
# Training accuracy = 15.10%, Testing accuracy = 18.10%
#
# Training accuracy = 14.60%, Testing accuracy = 17.70%
#
# Training accuracy = 14.40%, Testing accuracy = 17.40%
#
# Training accuracy = 16.40%, Testing accuracy = 16.90%
#
# Training accuracy = 15.10%, Testing accuracy = 18.30%
#
# Training accuracy = 13.80%, Testing accuracy = 17.60%
#
# Training accuracy = 16.20%, Testing accuracy = 18.40%
#
# Training accuracy = 13.00%, Testing accuracy = 18.60%
#
# Training accuracy = 13.80%, Testing accuracy = 16.60%
#
# Training accuracy = 14.10%, Testing accuracy = 19.90%
#
# Weight Sharing = False, Auxilary Loss = True
# Training accuracy = 15.60%, Testing accuracy = 19.90%
#
# Training accuracy = 12.10%, Testing accuracy = 17.90%
#
# Training accuracy = 12.10%, Testing accuracy = 16.70%
#
# Training accuracy = 10.50%, Testing accuracy = 16.60%
#
# Training accuracy = 16.00%, Testing accuracy = 17.70%
#
# Training accuracy = 11.40%, Testing accuracy = 18.10%
#
# Training accuracy = 12.40%, Testing accuracy = 18.10%
#
# Training accuracy = 12.90%, Testing accuracy = 16.90%
#
# Training accuracy = 13.70%, Testing accuracy = 21.00%
#
# Training accuracy = 12.30%, Testing accuracy = 17.50%
#
# Weight Sharing = True, Auxilary Loss = True
# Training accuracy = 5.60%, Testing accuracy = 12.90%
#
# Training accuracy = 9.70%, Testing accuracy = 12.60%
#
# Training accuracy = 8.60%, Testing accuracy = 13.20%
#
# Training accuracy = 8.20%, Testing accuracy = 13.30%
#
# Training accuracy = 8.20%, Testing accuracy = 11.90%
#
# Training accuracy = 7.60%, Testing accuracy = 13.00%
#
# Training accuracy = 10.40%, Testing accuracy = 14.70%
#
# Training accuracy = 6.50%, Testing accuracy = 10.80%
#
# Training accuracy = 7.50%, Testing accuracy = 12.30%
#
# Training accuracy = 7.30%, Testing accuracy = 12.90%

# %%
import numpy as np

# %%
print('**************** Baseline ***************')
print("Testing accuracy = {0:.2f} ± {1:.2f}".format(100 - np.mean(baseline_errors),
                                                    np.std(baseline_errors)))

print('**************** FullyConnected ***************')
print("Testing accuracy = {0:.2f} ± {1:.2f}".format(100 - np.mean(fully_errors),
                                                    np.std(fully_errors)))

print('**************** ResNet ***************')
print("Testing accuracy = {0:.2f} ± {1:.2f}".format(100 - np.mean(resnet_errors),
                                                    np.std(resnet_errors)))
# Out:
# **************** Baseline ***************
# Testing accuracy = 80.18 ± 1.58
# **************** FullyConnected ***************
# Testing accuracy = 76.86 ± 2.67
# **************** ResNet ***************
# Testing accuracy = 78.46 ± 1.39

# %%
print('**************** CNN ***************')
print('Weight Sharing = ''False'', Auxilary Loss = ''False''')
print("Testing accuracy = {0:.2f} ± {1:.2f}".format(100 - np.mean(cnn0_errors),
                                                    np.std(cnn0_errors)))
print('Weight Sharing = ''False'', Auxilary Loss = ''True''')
print("Testing accuracy = {0:.2f} ± {1:.2f}".format(100 - np.mean(cnn1_errors),
                                                    np.std(cnn1_errors)))
print('Weight Sharing = ''True'', Auxilary Loss = ''False''')
print("Testing accuracy = {0:.2f} ± {1:.2f}".format(100 - np.mean(cnn2_errors),
                                                    np.std(cnn2_errors)))
print('Weight Sharing = ''True'', Auxilary Loss = ''True''')
print("Testing accuracy = {0:.2f} ± {1:.2f}".format(100 - np.mean(cnn3_errors),
                                                    np.std(cnn3_errors)))
# Out:
# **************** CNN ***************
# Weight Sharing = False, Auxilary Loss = False
# Testing accuracy = 79.54 ± 3.50
# Weight Sharing = False, Auxilary Loss = True
# Testing accuracy = 84.27 ± 1.17
# Weight Sharing = True, Auxilary Loss = False
# Testing accuracy = 82.36 ± 2.54
# Weight Sharing = True, Auxilary Loss = True
# Testing accuracy = 87.15 ± 1.58

# %%
print('**************** LeNet ***************')
print('Weight Sharing = ''False'', Auxilary Loss = ''False''')
print("Testing accuracy = {0:.2f} ± {1:.2f}".format(100 - np.mean(lenet0_errors),
                                                    np.std(lenet0_errors)))
print('Weight Sharing = ''False'', Auxilary Loss = ''True''')
print("Testing accuracy = {0:.2f} ± {1:.2f}".format(100 - np.mean(lenet1_errors),
                                                    np.std(lenet1_errors)))
print('Weight Sharing = ''True'', Auxilary Loss = ''False''')
print("Testing accuracy = {0:.2f} ± {1:.2f}".format(100 - np.mean(lenet2_errors),
                                                    np.std(lenet2_errors)))
print('Weight Sharing = ''True'', Auxilary Loss = ''True''')
print("Testing accuracy = {0:.2f} ± {1:.2f}".format(100 - np.mean(lenet3_errors),
                                                    np.std(lenet3_errors)))
# Out:
# **************** LeNet ***************
# Weight Sharing = False, Auxilary Loss = False
# Testing accuracy = 76.40 ± 1.84
# Weight Sharing = False, Auxilary Loss = True
# Testing accuracy = 82.05 ± 0.89
# Weight Sharing = True, Auxilary Loss = False
# Testing accuracy = 81.96 ± 1.34
# Weight Sharing = True, Auxilary Loss = True
# Testing accuracy = 87.24 ± 0.96
